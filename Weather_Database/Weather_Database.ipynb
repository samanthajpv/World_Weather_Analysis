# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lat = np.random.uniform(low=-90.000, high=90.000, size=2000)
lng = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lng = zip(lat, lng)
lat_lng

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lng)

# %%
# Create list for holding the cities
cities = []

# Identify nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If city is unique, add to cities list
    if city not in cities:
        cities.append(city)
        
# Print city count to confirm sufficient count
len(cities)
# Out:
# 759

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create empty list to hold the weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc})

# If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | iqaluit
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | thinadhoo
# Processing Record 4 of Set 1 | katete
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | khatanga
# Processing Record 8 of Set 1 | jeremoabo
# Processing Record 9 of Set 1 | yeppoon
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | vung tau
# Processing Record 12 of Set 1 | codrington
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | nome
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | atuona
# Processing Record 18 of Set 1 | cabo rojo
# Processing Record 19 of Set 1 | chinhoyi
# Processing Record 20 of Set 1 | wattegama
# Processing Record 21 of Set 1 | dikson
# Processing Record 22 of Set 1 | ancud
# Processing Record 23 of Set 1 | smirnykh
# Processing Record 24 of Set 1 | tasiilaq
# Processing Record 25 of Set 1 | alofi
# Processing Record 26 of Set 1 | port lincoln
# Processing Record 27 of Set 1 | shingu
# Processing Record 28 of Set 1 | barrow
# Processing Record 29 of Set 1 | san pedro
# Processing Record 30 of Set 1 | hauterive
# Processing Record 31 of Set 1 | nancha
# Processing Record 32 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 1 | sao borja
# Processing Record 34 of Set 1 | high prairie
# Processing Record 35 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 1 | sosnovoborsk
# Processing Record 37 of Set 1 | pedro carbo
# Processing Record 38 of Set 1 | ushtobe
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | saint-joseph
# Processing Record 41 of Set 1 | progreso
# Processing Record 42 of Set 1 | severo-kurilsk
# Processing Record 43 of Set 1 | toul
# Processing Record 44 of Set 1 | vaini
# Processing Record 45 of Set 1 | pevek
# Processing Record 46 of Set 1 | kununurra
# Processing Record 47 of Set 1 | new norfolk
# Processing Record 48 of Set 1 | clyde river
# Processing Record 49 of Set 1 | faya
# Processing Record 50 of Set 1 | tuktoyaktuk
# Processing Record 1 of Set 2 | bubaque
# Processing Record 2 of Set 2 | mount gambier
# Processing Record 3 of Set 2 | ostrovnoy
# Processing Record 4 of Set 2 | kahului
# Processing Record 5 of Set 2 | cap malheureux
# Processing Record 6 of Set 2 | alyangula
# Processing Record 7 of Set 2 | carnarvon
# Processing Record 8 of Set 2 | kolondieba
# Processing Record 9 of Set 2 | saskylakh
# Processing Record 10 of Set 2 | marsh harbour
# Processing Record 11 of Set 2 | achisay
# City not found. Skipping...
# Processing Record 12 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 13 of Set 2 | tinskoy
# Processing Record 14 of Set 2 | victoria
# Processing Record 15 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 2 | bataipora
# Processing Record 17 of Set 2 | marienburg
# Processing Record 18 of Set 2 | lompoc
# Processing Record 19 of Set 2 | ponta delgada
# Processing Record 20 of Set 2 | port hedland
# Processing Record 21 of Set 2 | avarua
# Processing Record 22 of Set 2 | talara
# Processing Record 23 of Set 2 | matamoros
# Processing Record 24 of Set 2 | skelleftea
# Processing Record 25 of Set 2 | sao filipe
# Processing Record 26 of Set 2 | brae
# Processing Record 27 of Set 2 | jibuti
# Processing Record 28 of Set 2 | port blair
# Processing Record 29 of Set 2 | akil
# Processing Record 30 of Set 2 | santa maria da vitoria
# Processing Record 31 of Set 2 | berlevag
# Processing Record 32 of Set 2 | barranca
# Processing Record 33 of Set 2 | tuatapere
# Processing Record 34 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 2 | geraldton
# Processing Record 37 of Set 2 | bereda
# Processing Record 38 of Set 2 | sao benedito do rio preto
# Processing Record 39 of Set 2 | puerto ayora
# Processing Record 40 of Set 2 | ayagoz
# Processing Record 41 of Set 2 | sitka
# Processing Record 42 of Set 2 | lebu
# Processing Record 43 of Set 2 | hermanus
# Processing Record 44 of Set 2 | albanel
# Processing Record 45 of Set 2 | college
# Processing Record 46 of Set 2 | chuy
# Processing Record 47 of Set 2 | kaitangata
# Processing Record 48 of Set 2 | irmo
# Processing Record 49 of Set 2 | kavieng
# Processing Record 50 of Set 2 | ilulissat
# Processing Record 1 of Set 3 | norman wells
# Processing Record 2 of Set 3 | galesong
# Processing Record 3 of Set 3 | gladstone
# Processing Record 4 of Set 3 | abu samrah
# Processing Record 5 of Set 3 | asayita
# City not found. Skipping...
# Processing Record 6 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 3 | bredasdorp
# Processing Record 8 of Set 3 | asfi
# Processing Record 9 of Set 3 | upernavik
# Processing Record 10 of Set 3 | araouane
# Processing Record 11 of Set 3 | saint-philippe
# Processing Record 12 of Set 3 | ishinomaki
# Processing Record 13 of Set 3 | dujuma
# City not found. Skipping...
# Processing Record 14 of Set 3 | xichang
# Processing Record 15 of Set 3 | busselton
# Processing Record 16 of Set 3 | salalah
# Processing Record 17 of Set 3 | kodiak
# Processing Record 18 of Set 3 | vila franca do campo
# Processing Record 19 of Set 3 | abonnema
# Processing Record 20 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 22 of Set 3 | hilo
# Processing Record 23 of Set 3 | bengkulu
# Processing Record 24 of Set 3 | cherskiy
# Processing Record 25 of Set 3 | plettenberg bay
# Processing Record 26 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 3 | port alfred
# Processing Record 28 of Set 3 | broome
# Processing Record 29 of Set 3 | saint-georges
# Processing Record 30 of Set 3 | yara
# Processing Record 31 of Set 3 | mar del plata
# Processing Record 32 of Set 3 | hobart
# Processing Record 33 of Set 3 | cockburn harbour
# City not found. Skipping...
# Processing Record 34 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 3 | hithadhoo
# Processing Record 36 of Set 3 | wellsford
# Processing Record 37 of Set 3 | pisco
# Processing Record 38 of Set 3 | svrljig
# Processing Record 39 of Set 3 | talnakh
# Processing Record 40 of Set 3 | kapaa
# Processing Record 41 of Set 3 | halifax
# Processing Record 42 of Set 3 | lavrentiya
# Processing Record 43 of Set 3 | dzaoudzi
# Processing Record 44 of Set 3 | lagoa
# Processing Record 45 of Set 3 | jamestown
# Processing Record 46 of Set 3 | biloela
# Processing Record 47 of Set 3 | zapolyarnyy
# Processing Record 48 of Set 3 | ndende
# Processing Record 49 of Set 3 | peski
# Processing Record 50 of Set 3 | chokurdakh
# Processing Record 1 of Set 4 | luebo
# Processing Record 2 of Set 4 | rocha
# Processing Record 3 of Set 4 | singaraja
# Processing Record 4 of Set 4 | maun
# Processing Record 5 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 4 | cayenne
# Processing Record 7 of Set 4 | marrakesh
# Processing Record 8 of Set 4 | longyearbyen
# Processing Record 9 of Set 4 | gamba
# Processing Record 10 of Set 4 | east london
# Processing Record 11 of Set 4 | sault sainte marie
# Processing Record 12 of Set 4 | santa lucia
# Processing Record 13 of Set 4 | bu salim
# City not found. Skipping...
# Processing Record 14 of Set 4 | sistranda
# Processing Record 15 of Set 4 | faanui
# Processing Record 16 of Set 4 | bambous virieux
# Processing Record 17 of Set 4 | kihei
# Processing Record 18 of Set 4 | baykit
# Processing Record 19 of Set 4 | bambanglipuro
# Processing Record 20 of Set 4 | soe
# Processing Record 21 of Set 4 | butaritari
# Processing Record 22 of Set 4 | ribeira grande
# Processing Record 23 of Set 4 | barra do pirai
# Processing Record 24 of Set 4 | fortuna
# Processing Record 25 of Set 4 | souillac
# Processing Record 26 of Set 4 | georgetown
# Processing Record 27 of Set 4 | nemuro
# Processing Record 28 of Set 4 | boyuibe
# Processing Record 29 of Set 4 | cheuskiny
# City not found. Skipping...
# Processing Record 30 of Set 4 | kudahuvadhoo
# Processing Record 31 of Set 4 | prescott
# Processing Record 32 of Set 4 | thompson
# Processing Record 33 of Set 4 | verkhovye
# Processing Record 34 of Set 4 | vestmannaeyjar
# Processing Record 35 of Set 4 | carmo do paranaiba
# Processing Record 36 of Set 4 | sept-iles
# Processing Record 37 of Set 4 | nova vicosa
# Processing Record 38 of Set 4 | mahebourg
# Processing Record 39 of Set 4 | mayo
# Processing Record 40 of Set 4 | agirish
# Processing Record 41 of Set 4 | wloclawek
# Processing Record 42 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 43 of Set 4 | qaanaaq
# Processing Record 44 of Set 4 | itajobi
# Processing Record 45 of Set 4 | sortavala
# Processing Record 46 of Set 4 | bathsheba
# Processing Record 47 of Set 4 | narsaq
# Processing Record 48 of Set 4 | kamenka
# Processing Record 49 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 50 of Set 4 | terrace bay
# Processing Record 1 of Set 5 | ndjole
# Processing Record 2 of Set 5 | wladyslawowo
# Processing Record 3 of Set 5 | husavik
# Processing Record 4 of Set 5 | caravelas
# Processing Record 5 of Set 5 | matara
# Processing Record 6 of Set 5 | vidim
# Processing Record 7 of Set 5 | santa rosalia
# Processing Record 8 of Set 5 | mentok
# City not found. Skipping...
# Processing Record 9 of Set 5 | ahuimanu
# Processing Record 10 of Set 5 | kruisfontein
# Processing Record 11 of Set 5 | beloha
# Processing Record 12 of Set 5 | merida
# Processing Record 13 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 5 | balkhash
# Processing Record 15 of Set 5 | nara
# Processing Record 16 of Set 5 | luderitz
# Processing Record 17 of Set 5 | kholm
# Processing Record 18 of Set 5 | catamarca
# Processing Record 19 of Set 5 | hasaki
# Processing Record 20 of Set 5 | hamilton
# Processing Record 21 of Set 5 | krasnoselkup
# Processing Record 22 of Set 5 | weiswampach
# Processing Record 23 of Set 5 | campoverde
# Processing Record 24 of Set 5 | dauriya
# Processing Record 25 of Set 5 | vardo
# Processing Record 26 of Set 5 | makakilo city
# Processing Record 27 of Set 5 | saldanha
# Processing Record 28 of Set 5 | sola
# Processing Record 29 of Set 5 | beyneu
# Processing Record 30 of Set 5 | oulu
# Processing Record 31 of Set 5 | roma
# Processing Record 32 of Set 5 | kalanguy
# Processing Record 33 of Set 5 | katsuura
# Processing Record 34 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 5 | padang
# Processing Record 36 of Set 5 | belyy yar
# Processing Record 37 of Set 5 | srednekolymsk
# Processing Record 38 of Set 5 | surt
# Processing Record 39 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 5 | istria
# Processing Record 41 of Set 5 | kuhestan
# City not found. Skipping...
# Processing Record 42 of Set 5 | nikolskoye
# Processing Record 43 of Set 5 | letlhakane
# Processing Record 44 of Set 5 | port elizabeth
# Processing Record 45 of Set 5 | sinnamary
# Processing Record 46 of Set 5 | santa rosa
# Processing Record 47 of Set 5 | talcahuano
# Processing Record 48 of Set 5 | pombas
# Processing Record 49 of Set 5 | helsinki
# Processing Record 50 of Set 5 | grimmen
# Processing Record 1 of Set 6 | guiong
# Processing Record 2 of Set 6 | timra
# Processing Record 3 of Set 6 | saint george
# Processing Record 4 of Set 6 | puerto baquerizo moreno
# Processing Record 5 of Set 6 | yellowknife
# Processing Record 6 of Set 6 | gonaives
# Processing Record 7 of Set 6 | kearney
# Processing Record 8 of Set 6 | shubarkuduk
# Processing Record 9 of Set 6 | oyama
# Processing Record 10 of Set 6 | esperance
# Processing Record 11 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 6 | hammerfest
# Processing Record 13 of Set 6 | lima
# Processing Record 14 of Set 6 | richards bay
# Processing Record 15 of Set 6 | yulara
# Processing Record 16 of Set 6 | yirol
# City not found. Skipping...
# Processing Record 17 of Set 6 | guerrero negro
# Processing Record 18 of Set 6 | khani
# Processing Record 19 of Set 6 | quatre cocos
# Processing Record 20 of Set 6 | amapa
# Processing Record 21 of Set 6 | banmo
# City not found. Skipping...
# Processing Record 22 of Set 6 | tura
# Processing Record 23 of Set 6 | nizhnevartovsk
# Processing Record 24 of Set 6 | santiago del estero
# Processing Record 25 of Set 6 | vanino
# Processing Record 26 of Set 6 | mangan
# Processing Record 27 of Set 6 | awbari
# Processing Record 28 of Set 6 | somerset
# Processing Record 29 of Set 6 | isangel
# Processing Record 30 of Set 6 | odweyne
# Processing Record 31 of Set 6 | saint-augustin
# Processing Record 32 of Set 6 | askino
# Processing Record 33 of Set 6 | pandan
# Processing Record 34 of Set 6 | grindavik
# Processing Record 35 of Set 6 | eureka
# Processing Record 36 of Set 6 | shenjiamen
# Processing Record 37 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 6 | nishihara
# Processing Record 39 of Set 6 | muzhi
# Processing Record 40 of Set 6 | rawson
# Processing Record 41 of Set 6 | cravo norte
# Processing Record 42 of Set 6 | deputatskiy
# Processing Record 43 of Set 6 | aksarka
# Processing Record 44 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 6 | juba
# Processing Record 46 of Set 6 | san cristobal
# Processing Record 47 of Set 6 | campina verde
# Processing Record 48 of Set 6 | dianopolis
# City not found. Skipping...
# Processing Record 49 of Set 6 | urdoma
# Processing Record 50 of Set 6 | senanga
# Processing Record 1 of Set 7 | del rio
# Processing Record 2 of Set 7 | ugoofaaru
# Processing Record 3 of Set 7 | caohai
# Processing Record 4 of Set 7 | tiksi
# Processing Record 5 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 6 of Set 7 | nelson bay
# Processing Record 7 of Set 7 | burica
# City not found. Skipping...
# Processing Record 8 of Set 7 | urbandale
# Processing Record 9 of Set 7 | georgiyevskoye
# Processing Record 10 of Set 7 | donskoye
# Processing Record 11 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 7 | vysokogornyy
# Processing Record 13 of Set 7 | hambantota
# Processing Record 14 of Set 7 | cervo
# Processing Record 15 of Set 7 | belaya gora
# Processing Record 16 of Set 7 | valparaiso
# Processing Record 17 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 7 | ponta do sol
# Processing Record 19 of Set 7 | ukiah
# Processing Record 20 of Set 7 | arraial do cabo
# Processing Record 21 of Set 7 | paamiut
# Processing Record 22 of Set 7 | banda aceh
# Processing Record 23 of Set 7 | hay river
# Processing Record 24 of Set 7 | eirunepe
# Processing Record 25 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 26 of Set 7 | yelizovo
# Processing Record 27 of Set 7 | vacaria
# Processing Record 28 of Set 7 | berdigestyakh
# Processing Record 29 of Set 7 | yerbogachen
# Processing Record 30 of Set 7 | morro bay
# Processing Record 31 of Set 7 | filingue
# Processing Record 32 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 33 of Set 7 | dandong
# Processing Record 34 of Set 7 | avera
# Processing Record 35 of Set 7 | airai
# Processing Record 36 of Set 7 | graham
# Processing Record 37 of Set 7 | honiara
# Processing Record 38 of Set 7 | leningradskiy
# Processing Record 39 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 40 of Set 7 | namangan
# Processing Record 41 of Set 7 | mont-de-marsan
# Processing Record 42 of Set 7 | sidi ali
# Processing Record 43 of Set 7 | grimari
# City not found. Skipping...
# Processing Record 44 of Set 7 | goroka
# Processing Record 45 of Set 7 | atar
# Processing Record 46 of Set 7 | mattru
# Processing Record 47 of Set 7 | lingyuan
# Processing Record 48 of Set 7 | xingyi
# Processing Record 49 of Set 7 | beringovskiy
# Processing Record 50 of Set 7 | tsumeb
# Processing Record 1 of Set 8 | igarape-miri
# City not found. Skipping...
# Processing Record 2 of Set 8 | hrubieszow
# Processing Record 3 of Set 8 | egvekinot
# Processing Record 4 of Set 8 | wajima
# Processing Record 5 of Set 8 | praya
# Processing Record 6 of Set 8 | sisimiut
# Processing Record 7 of Set 8 | munkebo
# Processing Record 8 of Set 8 | manyana
# Processing Record 9 of Set 8 | chipinge
# Processing Record 10 of Set 8 | tessalit
# Processing Record 11 of Set 8 | aklavik
# Processing Record 12 of Set 8 | matay
# Processing Record 13 of Set 8 | edgewater
# Processing Record 14 of Set 8 | les cayes
# Processing Record 15 of Set 8 | paraiso
# Processing Record 16 of Set 8 | bassila
# Processing Record 17 of Set 8 | galiwinku
# City not found. Skipping...
# Processing Record 18 of Set 8 | porosozero
# Processing Record 19 of Set 8 | okhotsk
# Processing Record 20 of Set 8 | bethel
# Processing Record 21 of Set 8 | lazaro cardenas
# Processing Record 22 of Set 8 | vityazevo
# Processing Record 23 of Set 8 | tucuma
# Processing Record 24 of Set 8 | provideniya
# Processing Record 25 of Set 8 | collie
# Processing Record 26 of Set 8 | lorengau
# Processing Record 27 of Set 8 | byron bay
# Processing Record 28 of Set 8 | takoradi
# Processing Record 29 of Set 8 | evanston
# Processing Record 30 of Set 8 | lasa
# Processing Record 31 of Set 8 | rawlins
# Processing Record 32 of Set 8 | nanortalik
# Processing Record 33 of Set 8 | etchojoa
# Processing Record 34 of Set 8 | paramonga
# Processing Record 35 of Set 8 | suicheng
# Processing Record 36 of Set 8 | sanchursk
# Processing Record 37 of Set 8 | san patricio
# Processing Record 38 of Set 8 | saint-leu
# Processing Record 39 of Set 8 | la ronge
# Processing Record 40 of Set 8 | savannah bight
# Processing Record 41 of Set 8 | puerto ayacucho
# Processing Record 42 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 43 of Set 8 | urumqi
# Processing Record 44 of Set 8 | dzilam gonzalez
# Processing Record 45 of Set 8 | uga
# Processing Record 46 of Set 8 | tha chang
# Processing Record 47 of Set 8 | mehamn
# Processing Record 48 of Set 8 | neiafu
# Processing Record 49 of Set 8 | fairlie
# Processing Record 50 of Set 8 | bonthe
# Processing Record 1 of Set 9 | karlskrona
# Processing Record 2 of Set 9 | zhezkazgan
# Processing Record 3 of Set 9 | sibolga
# Processing Record 4 of Set 9 | nizhniy baskunchak
# Processing Record 5 of Set 9 | gat
# Processing Record 6 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 7 of Set 9 | obihiro
# Processing Record 8 of Set 9 | praia
# Processing Record 9 of Set 9 | sapa
# Processing Record 10 of Set 9 | xuanhua
# Processing Record 11 of Set 9 | manggar
# Processing Record 12 of Set 9 | sisophon
# Processing Record 13 of Set 9 | nioro
# Processing Record 14 of Set 9 | orebro
# Processing Record 15 of Set 9 | ust-nera
# Processing Record 16 of Set 9 | aksu
# Processing Record 17 of Set 9 | ketchikan
# Processing Record 18 of Set 9 | ulaanbaatar
# Processing Record 19 of Set 9 | callaguip
# Processing Record 20 of Set 9 | humaita
# Processing Record 21 of Set 9 | san quintin
# Processing Record 22 of Set 9 | linjiang
# Processing Record 23 of Set 9 | palmer
# Processing Record 24 of Set 9 | dalinghe
# City not found. Skipping...
# Processing Record 25 of Set 9 | mukhen
# Processing Record 26 of Set 9 | sorland
# Processing Record 27 of Set 9 | kirkland lake
# Processing Record 28 of Set 9 | cairns
# Processing Record 29 of Set 9 | patacamaya
# Processing Record 30 of Set 9 | ak-dovurak
# Processing Record 31 of Set 9 | bilma
# Processing Record 32 of Set 9 | arlit
# Processing Record 33 of Set 9 | wamba
# Processing Record 34 of Set 9 | sainte-anne-des-monts
# Processing Record 35 of Set 9 | micheweni
# Processing Record 36 of Set 9 | vostok
# Processing Record 37 of Set 9 | yarmouth
# Processing Record 38 of Set 9 | agadez
# Processing Record 39 of Set 9 | westport
# Processing Record 40 of Set 9 | smidovich
# Processing Record 41 of Set 9 | yarada
# Processing Record 42 of Set 9 | torbay
# Processing Record 43 of Set 9 | kalmar
# Processing Record 44 of Set 9 | rockhampton
# Processing Record 45 of Set 9 | bowen
# Processing Record 46 of Set 9 | namibe
# Processing Record 47 of Set 9 | maturin
# Processing Record 48 of Set 9 | pittsfield
# Processing Record 49 of Set 9 | pangnirtung
# Processing Record 50 of Set 9 | assare
# Processing Record 1 of Set 10 | los llanos de aridane
# Processing Record 2 of Set 10 | oranjemund
# Processing Record 3 of Set 10 | umm lajj
# Processing Record 4 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 5 of Set 10 | zile
# Processing Record 6 of Set 10 | walvis bay
# Processing Record 7 of Set 10 | sinegorye
# Processing Record 8 of Set 10 | naze
# Processing Record 9 of Set 10 | gornyy
# Processing Record 10 of Set 10 | fairbanks
# Processing Record 11 of Set 10 | diffa
# Processing Record 12 of Set 10 | nicoya
# Processing Record 13 of Set 10 | coquimbo
# Processing Record 14 of Set 10 | bay roberts
# Processing Record 15 of Set 10 | piranshahr
# Processing Record 16 of Set 10 | san andres
# Processing Record 17 of Set 10 | illapel
# Processing Record 18 of Set 10 | clyde
# Processing Record 19 of Set 10 | ampanihy
# Processing Record 20 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 10 | iracoubo
# Processing Record 22 of Set 10 | doha
# Processing Record 23 of Set 10 | bodri
# Processing Record 24 of Set 10 | rolla
# Processing Record 25 of Set 10 | hokitika
# Processing Record 26 of Set 10 | saint-pierre
# Processing Record 27 of Set 10 | irece
# Processing Record 28 of Set 10 | hazorasp
# Processing Record 29 of Set 10 | the pas
# Processing Record 30 of Set 10 | zaraza
# Processing Record 31 of Set 10 | dingle
# Processing Record 32 of Set 10 | otavi
# Processing Record 33 of Set 10 | maluso
# Processing Record 34 of Set 10 | saint paul
# Processing Record 35 of Set 10 | port-gentil
# Processing Record 36 of Set 10 | pauini
# Processing Record 37 of Set 10 | vao
# Processing Record 38 of Set 10 | sena madureira
# Processing Record 39 of Set 10 | sabang
# Processing Record 40 of Set 10 | alice springs
# Processing Record 41 of Set 10 | tocache
# Processing Record 42 of Set 10 | kilindoni
# Processing Record 43 of Set 10 | comodoro rivadavia
# Processing Record 44 of Set 10 | bata
# Processing Record 45 of Set 10 | gangotri
# City not found. Skipping...
# Processing Record 46 of Set 10 | baherden
# Processing Record 47 of Set 10 | kitimat
# Processing Record 48 of Set 10 | freeport
# Processing Record 49 of Set 10 | sakakah
# Processing Record 50 of Set 10 | hofn
# Processing Record 1 of Set 11 | sambava
# Processing Record 2 of Set 11 | alenquer
# Processing Record 3 of Set 11 | launceston
# Processing Record 4 of Set 11 | superior
# Processing Record 5 of Set 11 | cintalapa
# Processing Record 6 of Set 11 | krasnogorsk
# Processing Record 7 of Set 11 | lac du bonnet
# Processing Record 8 of Set 11 | portland
# Processing Record 9 of Set 11 | hami
# Processing Record 10 of Set 11 | mpanda
# Processing Record 11 of Set 11 | meulaboh
# Processing Record 12 of Set 11 | am timan
# Processing Record 13 of Set 11 | worcester
# Processing Record 14 of Set 11 | udachnyy
# Processing Record 15 of Set 11 | maracas
# Processing Record 16 of Set 11 | poitiers
# Processing Record 17 of Set 11 | henties bay
# Processing Record 18 of Set 11 | ulladulla
# Processing Record 19 of Set 11 | wanaka
# Processing Record 20 of Set 11 | kuytun
# Processing Record 21 of Set 11 | ballina
# Processing Record 22 of Set 11 | biryusinsk
# Processing Record 23 of Set 11 | olinda
# Processing Record 24 of Set 11 | samarai
# Processing Record 25 of Set 11 | kyrksaeterora
# Processing Record 26 of Set 11 | ust-tsilma
# Processing Record 27 of Set 11 | aranos
# Processing Record 28 of Set 11 | vilhena
# Processing Record 29 of Set 11 | valdivia
# Processing Record 30 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 31 of Set 11 | boali
# Processing Record 32 of Set 11 | port arthur
# Processing Record 33 of Set 11 | port macquarie
# Processing Record 34 of Set 11 | lixourion
# Processing Record 35 of Set 11 | shimoda
# Processing Record 36 of Set 11 | yagodnoye
# Processing Record 37 of Set 11 | changli
# Processing Record 38 of Set 11 | maceio
# Processing Record 39 of Set 11 | aksarayskiy
# Processing Record 40 of Set 11 | tabuk
# Processing Record 41 of Set 11 | pushkinskiye gory
# Processing Record 42 of Set 11 | uvira
# Processing Record 43 of Set 11 | san antonio
# Processing Record 44 of Set 11 | miri
# Processing Record 45 of Set 11 | ridge
# Processing Record 46 of Set 11 | asuncion
# Processing Record 47 of Set 11 | tautira
# Processing Record 48 of Set 11 | mangrol
# Processing Record 49 of Set 11 | vila velha
# Processing Record 50 of Set 11 | lashio
# Processing Record 1 of Set 12 | khartoum
# Processing Record 2 of Set 12 | kotido
# Processing Record 3 of Set 12 | ylivieska
# Processing Record 4 of Set 12 | jiblah
# Processing Record 5 of Set 12 | baie-comeau
# Processing Record 6 of Set 12 | kargil
# Processing Record 7 of Set 12 | yialos
# City not found. Skipping...
# Processing Record 8 of Set 12 | aanekoski
# Processing Record 9 of Set 12 | qrendi
# Processing Record 10 of Set 12 | meadow lake
# Processing Record 11 of Set 12 | constitucion
# Processing Record 12 of Set 12 | sibut
# Processing Record 13 of Set 12 | lucea
# Processing Record 14 of Set 12 | hohhot
# Processing Record 15 of Set 12 | vologda
# Processing Record 16 of Set 12 | palana
# Processing Record 17 of Set 12 | brooks
# Processing Record 18 of Set 12 | inderborskiy
# City not found. Skipping...
# Processing Record 19 of Set 12 | cabo san lucas
# Processing Record 20 of Set 12 | verkhoyansk
# Processing Record 21 of Set 12 | dzhebariki-khaya
# Processing Record 22 of Set 12 | santa cruz cabralia
# Processing Record 23 of Set 12 | olafsvik
# Processing Record 24 of Set 12 | nebbi
# Processing Record 25 of Set 12 | santa maria
# Processing Record 26 of Set 12 | bogatoye
# Processing Record 27 of Set 12 | aswan
# Processing Record 28 of Set 12 | hirara
# Processing Record 29 of Set 12 | areka
# Processing Record 30 of Set 12 | hidrolandia
# Processing Record 31 of Set 12 | calderitas
# Processing Record 32 of Set 12 | korla
# Processing Record 33 of Set 12 | tupik
# Processing Record 34 of Set 12 | christchurch
# Processing Record 35 of Set 12 | marathon
# Processing Record 36 of Set 12 | armacao dos buzios
# City not found. Skipping...
# Processing Record 37 of Set 12 | san ignacio
# Processing Record 38 of Set 12 | buraydah
# Processing Record 39 of Set 12 | sompeta
# Processing Record 40 of Set 12 | olginskaya
# Processing Record 41 of Set 12 | pedasi
# Processing Record 42 of Set 12 | sorong
# Processing Record 43 of Set 12 | palasa
# Processing Record 44 of Set 12 | borujan
# City not found. Skipping...
# Processing Record 45 of Set 12 | ulaangom
# Processing Record 46 of Set 12 | krapivinskiy
# Processing Record 47 of Set 12 | mudgal
# Processing Record 48 of Set 12 | harper
# Processing Record 49 of Set 12 | karaton
# Processing Record 50 of Set 12 | salinas
# Processing Record 1 of Set 13 | teknaf
# Processing Record 2 of Set 13 | santarem
# Processing Record 3 of Set 13 | san blas
# Processing Record 4 of Set 13 | ponca city
# Processing Record 5 of Set 13 | uige
# Processing Record 6 of Set 13 | changji
# Processing Record 7 of Set 13 | cidreira
# Processing Record 8 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 9 of Set 13 | nalut
# Processing Record 10 of Set 13 | araguacu
# Processing Record 11 of Set 13 | machachi
# Processing Record 12 of Set 13 | klaksvik
# Processing Record 13 of Set 13 | zaragoza
# Processing Record 14 of Set 13 | ambanja
# Processing Record 15 of Set 13 | ahipara
# Processing Record 16 of Set 13 | moerai
# Processing Record 17 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 18 of Set 13 | cortez
# Processing Record 19 of Set 13 | tazovskiy
# Processing Record 20 of Set 13 | sechura
# Processing Record 21 of Set 13 | vanimo
# Processing Record 22 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 23 of Set 13 | ixtapa
# Processing Record 24 of Set 13 | puerto cabezas
# Processing Record 25 of Set 13 | ayan
# Processing Record 26 of Set 13 | lipin bor
# Processing Record 27 of Set 13 | aquiraz
# Processing Record 28 of Set 13 | te anau
# Processing Record 29 of Set 13 | dong xoai
# Processing Record 30 of Set 13 | osoyoos
# Processing Record 31 of Set 13 | gizo
# Processing Record 32 of Set 13 | zenzeli
# Processing Record 33 of Set 13 | alta floresta
# Processing Record 34 of Set 13 | conde
# Processing Record 35 of Set 13 | yar-sale
# Processing Record 36 of Set 13 | altagracia de orituco
# Processing Record 37 of Set 13 | gazojak
# Processing Record 38 of Set 13 | sliven
# Processing Record 39 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 13 | cascais
# Processing Record 41 of Set 13 | brza palanka
# Processing Record 42 of Set 13 | caucaia
# Processing Record 43 of Set 13 | storforshei
# Processing Record 44 of Set 13 | gazli
# Processing Record 45 of Set 13 | alugan
# Processing Record 46 of Set 13 | gunjur
# Processing Record 47 of Set 13 | itarema
# Processing Record 48 of Set 13 | rio grande
# Processing Record 49 of Set 13 | kuito
# Processing Record 50 of Set 13 | najran
# Processing Record 1 of Set 14 | totma
# Processing Record 2 of Set 14 | martinsburg
# Processing Record 3 of Set 14 | koumac
# Processing Record 4 of Set 14 | tayu
# Processing Record 5 of Set 14 | nhulunbuy
# Processing Record 6 of Set 14 | coihaique
# Processing Record 7 of Set 14 | parabel
# Processing Record 8 of Set 14 | biak
# Processing Record 9 of Set 14 | lachi
# Processing Record 10 of Set 14 | huarmey
# Processing Record 11 of Set 14 | fort walton beach
# Processing Record 12 of Set 14 | saryshagan
# City not found. Skipping...
# Processing Record 13 of Set 14 | sur
# Processing Record 14 of Set 14 | ishigaki
# Processing Record 15 of Set 14 | sheregesh
# Processing Record 16 of Set 14 | sai buri
# Processing Record 17 of Set 14 | el fuerte
# Processing Record 18 of Set 14 | ardistan
# City not found. Skipping...
# Processing Record 19 of Set 14 | kholuy
# Processing Record 20 of Set 14 | rochegda
# Processing Record 21 of Set 14 | miles city
# Processing Record 22 of Set 14 | huzhou
# Processing Record 23 of Set 14 | dali
# Processing Record 24 of Set 14 | daru
# Processing Record 25 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 26 of Set 14 | nuuk
# Processing Record 27 of Set 14 | kachug
# Processing Record 28 of Set 14 | camacha
# Processing Record 29 of Set 14 | bud
# Processing Record 30 of Set 14 | kajaani
# Processing Record 31 of Set 14 | portgordon
# Processing Record 32 of Set 14 | diego de almagro
# Processing Record 33 of Set 14 | belomorsk
# Processing Record 34 of Set 14 | mbarara
# Processing Record 35 of Set 14 | san carlos de bariloche
# Processing Record 36 of Set 14 | tignere
# Processing Record 37 of Set 14 | chapel hill
# Processing Record 38 of Set 14 | kungurtug
# Processing Record 39 of Set 14 | hyeres
# Processing Record 40 of Set 14 | barreirinhas
# Processing Record 41 of Set 14 | lao cai
# Processing Record 42 of Set 14 | celestun
# Processing Record 43 of Set 14 | lieksa
# Processing Record 44 of Set 14 | uyuni
# Processing Record 45 of Set 14 | mount isa
# Processing Record 46 of Set 14 | cozumel
# Processing Record 47 of Set 14 | seoul
# Processing Record 48 of Set 14 | coahuayana
# Processing Record 49 of Set 14 | knysna
# Processing Record 50 of Set 14 | aykhal
# Processing Record 1 of Set 15 | merauke
# Processing Record 2 of Set 15 | mayor pablo lagerenza
# Processing Record 3 of Set 15 | mount darwin
# Processing Record 4 of Set 15 | rexburg
# Processing Record 5 of Set 15 | nefteyugansk
# Processing Record 6 of Set 15 | bahia blanca
# Processing Record 7 of Set 15 | bandarbeyla
# Processing Record 8 of Set 15 | laguna
# Processing Record 9 of Set 15 | dawei
# Processing Record 10 of Set 15 | contai
# Processing Record 11 of Set 15 | batagay-alyta
# Processing Record 12 of Set 15 | lodwar
# Processing Record 13 of Set 15 | hobyo
# Processing Record 14 of Set 15 | nador
# Processing Record 15 of Set 15 | great yarmouth
# Processing Record 16 of Set 15 | hovd
# Processing Record 17 of Set 15 | seydi
# Processing Record 18 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 19 of Set 15 | kalemie
# Processing Record 20 of Set 15 | haines junction
# Processing Record 21 of Set 15 | prince rupert
# Processing Record 22 of Set 15 | madhupur
# Processing Record 23 of Set 15 | kosonsoy
# Processing Record 24 of Set 15 | asau
# Processing Record 25 of Set 15 | vinh
# Processing Record 26 of Set 15 | racine
# Processing Record 27 of Set 15 | adrar
# Processing Record 28 of Set 15 | mogadishu
# Processing Record 29 of Set 15 | maniitsoq
# Processing Record 30 of Set 15 | doume
# Processing Record 31 of Set 15 | zhanaozen
# Processing Record 32 of Set 15 | camana
# Processing Record 33 of Set 15 | anadyr
# Processing Record 34 of Set 15 | kharp
# Processing Record 35 of Set 15 | jalu
# Processing Record 36 of Set 15 | itacare
# Processing Record 37 of Set 15 | steinhagen
# Processing Record 38 of Set 15 | ilek
# Processing Record 39 of Set 15 | santo tomas
# Processing Record 40 of Set 15 | urla
# Processing Record 41 of Set 15 | zhangye
# Processing Record 42 of Set 15 | dunedin
# Processing Record 43 of Set 15 | privas
# Processing Record 44 of Set 15 | karatau
# Processing Record 45 of Set 15 | hashtgerd
# Processing Record 46 of Set 15 | breves
# Processing Record 47 of Set 15 | seara
# Processing Record 48 of Set 15 | bani
# Processing Record 49 of Set 15 | raudeberg
# Processing Record 50 of Set 15 | grand gaube
# Processing Record 1 of Set 16 | zhuhai
# Processing Record 2 of Set 16 | pacific grove
# Processing Record 3 of Set 16 | kano
# Processing Record 4 of Set 16 | severobaykalsk
# Processing Record 5 of Set 16 | mikhaylovka
# Processing Record 6 of Set 16 | labuhan
# Processing Record 7 of Set 16 | newport
# Processing Record 8 of Set 16 | novyy urengoy
# Processing Record 9 of Set 16 | suez
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Iqaluit      CA  63.7506  -68.5145     46.13        75          90
# 1     Albany      US  42.6001  -73.9662     72.75        84          53
# 2  Thinadhoo      MV   0.5333   72.9333     81.37        75         100
# 3     Katete      UG  -0.7818   29.7544     69.48        55         100
# 4    Mataura      NZ -46.1927  168.8643     46.47        97         100
# 5      Bluff      NZ -46.6000  168.3333     46.80        67          84
# 6   Khatanga      RU  71.9667  102.5000     53.82        92         100
# 7  Jeremoabo      BR -10.0750  -38.4808     67.37        83           8
# 8    Yeppoon      AU -23.1333  150.7333     53.38        48           0
# 9     Castro      BR -24.7911  -50.0119     50.50        60           6
#
#    Wind Speed Current Description
# 0       11.01     overcast clouds
# 1        6.67       broken clouds
# 2        6.96     overcast clouds
# 3        1.05     overcast clouds
# 4        2.39     overcast clouds
# 5       11.41       broken clouds
# 6        2.08     overcast clouds
# 7        8.81           clear sky
# 8        5.35           clear sky
# 9        2.33           clear sky

# %%
# Create the output file (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
